# %%
% matplotlib inline
from __future__ import division

import numpy as np
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# Out:
# /Users/sclayton/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# import the data
# pro ecotypes
filePath = r'/Users/sclayton/Documents/physics-traits/data/Liverpool_phytoplankton_database_original.xls'
all_data = pd.read_excel(filePath, sheetname = 'all data')

mean = pd.read_excel(filePath, sheetname = 'mean data')

print all_data.columns
# Out:
# Index([u'Phyto ENL', u'Dataset', u'Species', u'Ref', u'XLS', u'ENL', u'Temp C',
#        u'µ (d-1)', u'cell volume', u'T - Tµmean', u'(µ - µmean) ¸ mmean',
#        u'(µ - µT15)/µT15', u'Daylength (hours)', u'Irradiance ', u'µmax',
#        u'Temp at µmax', u'Exp. Temp range', u'Mean Temp.',
#        u'Linear slope parameter', u'Trophy (A = 1, possibility of M = 2, )',
#        u'Habitat (Pla = 1, Ben = 2)', u'Functional group', u'Salinity',
#        u'Salinity (cat.) 1 = FW, 2 = Bra, 3 = Mar', u'Growth measure',
#        u'Red-Growth measure 1= count, 2= chla based, 3 = colorimeter/density, 4=dilution/radioactive',
#        u'(Data) mean CV (µm3)', u'Log Mean CV', u'(Lit) mean C V (µm3)',
#        u'(Data) Temp at Mean CV', u'(Data)Mean cell mass (pg C cell -1)',
#        u'volume: mass conversion', u'Daylength (hours) at µmax',
#        u'Irradiance at µmax',
#        u'Type of irradiance measurement (Radiometric=1, Quantum=2)', u'Taxa',
# ...

# %%
species = pd.unique(all_data['Species'])

for s in species:
    print s, np.mean(all_data.loc[(all_data['Species']==s),['Temp C']])
# Out:
# Plagiotropis sp.  Temp C    12.265957
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1964 Temp C    6.25
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1965 Temp C    6.25
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1966 Temp C    6.25
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1967 Temp C    7.75
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1968 Temp C    7.75
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1969 Temp C    7.75
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1970 Temp C    9
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1971 Temp C    9.25
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1972 Temp C    10.5
# dtype: float64
# Cylindrotheca closterium (Ehrenberg) Reimann & Lewin 1973 Temp C    10.5
# dtype: float64
# ...
